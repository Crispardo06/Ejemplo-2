# %% [markdown]
# <a href="https://colab.research.google.com/github/Crispardo06/Ejemplo-2/blob/main/C%C3%B3digo_en_Python_para_resolver_una_ecuaci%C3%B3n_diferencial_de_primer_orden_dy_dt%3D_2y_o_dy_dt_2y%3D0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# Definir la ecuación diferencial
def sistema(t, y, coef):
    return -coef * y

# Parámetros del sistema
params = {
    "coeficiente": 40,  # Valor del coeficiente en la ecuación -2y
    "y0": 10,           # Condición inicial
    "t_inicio": 2,     # Tiempo inicial
    "t_final": 8,      # Tiempo final
    "num_puntos": 50  # Número de puntos en la simulación
}

# Rango de tiempo y evaluación
t_eval = np.linspace(params["t_inicio"], params["t_final"], params["num_puntos"])

# Resolver la ecuación diferencial
sol = solve_ivp(sistema, [params["t_inicio"], params["t_final"]], [params["y0"]],
                args=(params["coeficiente"],), t_eval=t_eval)

# Mostrar datos de entrada
print("Datos de Entrada:")
print(f"Coeficiente: {params['coeficiente']}")
print(f"Condición inicial: y0 = {params['y0']}")
print(f"Intervalo de tiempo: [{params['t_inicio']}, {params['t_final']}]\n")

# Mostrar datos de salida (primeros 10 valores)
print("Datos de Salida: (Primeros 10 puntos)")
for i in range(10):
    print(f"Tiempo: {sol.t[i]:.2f} s, y: {sol.y[0, i]:.4f}")

# Color personalizable de la gráfica
color_grafica = "red"  # Cambia el color aquí ('red', 'green', etc.)

# Graficar la solución
plt.plot(sol.t, sol.y[0], color=color_grafica, label="y(t)")
plt.title("Solución de dy/dt + 2y = 0")
plt.xlabel("Tiempo (s)")
plt.ylabel("y(t)")
plt.legend()
plt.grid()
plt.show()
# Out:
# Datos de Entrada:
# Coeficiente: 40
# Condición inicial: y0 = 10
# Intervalo de tiempo: [2, 8]
#
# Datos de Salida: (Primeros 10 puntos)
# Tiempo: 2.00 s, y: 10.0000
# Tiempo: 2.12 s, y: 0.0748
# Tiempo: 2.24 s, y: 0.0006
# Tiempo: 2.37 s, y: 0.0000
# Tiempo: 2.49 s, y: -0.0000
# Tiempo: 2.61 s, y: -0.0000
# Tiempo: 2.73 s, y: 0.0000
# Tiempo: 2.86 s, y: -0.0000
# Tiempo: 2.98 s, y: 0.0000
# Tiempo: 3.10 s, y: -0.0000
